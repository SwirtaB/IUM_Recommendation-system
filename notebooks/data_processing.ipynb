# %%
import pandas as pd
import numpy as np

usersDF = pd.read_json("./data/processed/users.json")
sessionsDF = pd.read_json("./data/processed/sessions.json")
productsDF = pd.read_json("./data/processed/products.json")
deliveriesDF = pd.read_json("./data/processed/deliveries.json")

# %%
sessionsDF.describe()
# Out:
#           session_id        user_id     product_id  offered_discount  \
# count  125146.000000  125146.000000  125146.000000     125146.000000
# mean    10798.379613     198.774991    1119.171080          4.973431
# std      6154.039932      58.170661     104.596897          7.080321
# min       124.000000     102.000000    1001.000000          0.000000
# 25%      5472.000000     151.000000    1048.000000          0.000000
# 50%     10814.000000     195.000000    1057.000000          0.000000
# 75%     16166.000000     248.000000    1227.000000         10.000000
# max     21382.000000     301.000000    1319.000000         20.000000
#
#         purchase_id
# count  10893.000000
# mean   25447.000000
# std     3144.682575
# min    20001.000000
# 25%    22724.000000
# 50%    25447.000000
# 75%    28170.000000
# max    30893.000000

# %%
purchaseSessions = sessionsDF.dropna()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Sessions data group by user_id

# %%
groupedSessionsDF = sessionsDF.groupby(["user_id"])
groupedSessionsDF.describe()
# Out:
#         session_id                                                      \
#              count          mean        std      min      25%      50%
# user_id
# 102          729.0    187.449931  34.831707    124.0    160.0    187.0
# 103         1185.0    340.972996  52.504063    248.0    295.0    345.0
# 104          915.0    507.349727  47.928627    432.0    466.0    502.0
# 105          464.0    633.306034  26.629144    590.0    608.0    639.0
# 106           55.0    681.690909   2.747880    678.0    679.0    682.0
# ...            ...           ...        ...      ...      ...      ...
# 297         1171.0  20855.317677  54.966282  20764.0  20806.0  20854.0
# 298          731.0  21009.532148  33.629895  20951.0  20983.0  21010.0
# 299          764.0  21134.738220  38.835703  21069.0  21102.0  21136.0
# 300          587.0  21251.015332  28.816320  21202.0  21226.0  21253.0
# 301          572.0  21344.646853  21.509769  21305.0  21327.0  21346.0
#
# ...
